# %%
from kerykeion import NatalAspects, AstrologicalSubject, Report
from grand_key_0_4_0 import grand_key, rulership_for_planets
from grand_key_outputs import aspect_table, text_output, symbol_output
from chart_astro_seek import test_astro_seek_chart, download_chart_image, draw_aspect_lines

# %%
a_subject = AstrologicalSubject(name="Karl Liebknecht",year= 1871,month= 8,day=13,hour=8,minute=00,nation="DE",city="Leipzig",lat=51,lng=12)

# %%
Report(a_subject).print_report()
# Out:
# +- Kerykeion report for Karl Liebknecht -+
# +-----------+------+-------------+-----------+----------+
# | Date      | Time | Location    | Longitude | Latitude |
# +-----------+------+-------------+-----------+----------+
# | 13/8/1871 | 8:0  | Leipzig, DE | 12.37129  | 51.33962 |
# +-----------+------+-------------+-----------+----------+
# +-----------+------+-------+------+-------+
# | Planet    | Sign | Pos.  | Ret. | House |
# +-----------+------+-------+------+-------+
# | Sun       | Leo  | 20.05 | -    | H12   |
# | Moon      | Can  | 15.87 | -    | H11   |
# | Mercury   | Vir  | 15.94 | -    | H1    |
# | Venus     | Lib  | 2.3   | -    | H2    |
# | Mars      | Sco  | 0.39  | -    | H3    |
# | Jupiter   | Can  | 17.98 | -    | H11   |
# | Saturn    | Cap  | 3.78  | R    | H5    |
# | Uranus    | Can  | 28.32 | -    | H11   |
# | Neptune   | Ari  | 24.01 | R    | H8    |
# | Pluto     | Tau  | 19.87 | -    | H9    |
# | Mean_Node | Gem  | 28.16 | R    | H10   |
# | True_Node | Gem  | 29.9  | R    | H10   |
# | ASC       | Vir  | 23.22 | -    | H1    |
# | MC        | Gem  | 21.18 | R    | H10   |
# +-----------+------+-------+------+-------+
# +-------+------+----------+
# | House | Sign | Position |
# +-------+------+----------+
# | H1    | Vir  | 0.0      |
# | H2    | Lib  | 0.0      |
# | H3    | Sco  | 0.0      |
# | H4    | Sag  | 0.0      |
# | H5    | Cap  | 0.0      |
# | H6    | Aqu  | 0.0      |
# | H7    | Pis  | 0.0      |
# | H8    | Ari  | 0.0      |
# | H9    | Tau  | 0.0      |
# | H10   | Gem  | 0.0      |
# | H11   | Can  | 0.0      |
# | H12   | Leo  | 0.0      |
# +-------+------+----------+

# %%
chart = test_astro_seek_chart(a_subject)
download = download_chart_image(chart)
result_image = draw_aspect_lines(a_subject, str(download))
# Out:
# Chart image downloaded successfully: charts_downloads\horoscope-chart4-700__radix_astroseek_customized_13-8-1871_8-0.png

# %%
aspect_table(a_subject)
# Out:
#    p1_name  p1_abs_pos  p2_name  p2_abs_pos       aspect     orbit  \
# 1      Sun  140.050850  Neptune   24.011726        trine -3.960875
# 2      Sun  140.050850    Pluto   49.872805       square  0.178045
# 3     Moon  105.873158  Mercury  165.942570      sextile  0.069413
# 4     Moon  105.873158  Jupiter  107.979916  conjunction  2.106758
# 5  Mercury  165.942570  Jupiter  107.979916      sextile -2.037345
# 6  Mercury  165.942570    Pluto   49.872805        trine -3.930235
# 7    Venus  182.298528   Saturn  273.780910       square  1.482382
# 8  Jupiter  107.979916    Pluto   49.872805      sextile -1.892890
# 9   Uranus  118.321984  Neptune   24.011726       square  4.310258
#
#    aspect_degrees    color  aid        diff  p1  p2
# 1             120  #0000FF    6  116.039125   0   8
# 2              90  #FF0000    5   90.178045   0   9
# 3              60  #0000FF    3   60.069413   1   2
# 4               0  #FF0000    0    2.106758   1   5
# 5              60  #0000FF    3   57.962655   2   5
# 6             120  #0000FF    6  116.069765   2   9
# 7              90  #FF0000    5   91.482382   3   6
# 8              60  #0000FF    3   58.107110   5   9
# 9              90  #FF0000    5   94.310258   7   8

# %%
rulership_for_planets(a_subject)
# Out:
# 1. Sun in Leo -> in H12 -> ruled by Sun -> ruler in Leo -> in H12
# 2. Moon in Can -> in H11 -> ruled by Moon -> ruler in Can -> in H11
# 3. Mercury in Vir -> in H1 -> ruled by Mercury -> ruler in Vir -> in H1
# 4. Venus in Lib -> in H2 -> ruled by Venus -> ruler in Lib -> in H2
# 5. Mars in Sco -> in H3 -> ruled by Mars -> ruler in Sco -> in H3
# 6. Jupiter in Can -> in H11 -> ruled by Moon -> ruler in Can -> in H11
# 7. Saturn in Cap -> in H5 -> ruled by Saturn -> ruler in Cap -> in H5
# 8. Uranus in Can -> in H11 -> ruled by Moon -> ruler in Can -> in H11
# 9. Neptune in Ari -> in H8 -> ruled by Mars -> ruler in Sco -> in H3
# 10. Pluto in Tau -> in H9 -> ruled by Venus -> ruler in Lib -> in H2

# %%
key_array = grand_key(a_subject)
text_output(key_array)
# Out:
# Sun Leo H12 |trine Neptune Ari H8
# Sun Leo H12 |square Pluto Tau H9
# Moon Can H11 |sextile Mercury Vir H1 H10
# Moon Can H11 |conjunction Jupiter H4 H7
# Mercury Vir H1 |sextile Moon Can H11 |sextile Jupiter Can H11 H4 H7
# Mercury Vir H1 |trine Pluto Tau H9
# Venus Lib H2 |square Saturn Cap H5 H6
# Jupiter Can H11 |conjunction Moon
# Jupiter Can H11 |sextile Mercury Vir H1 H10 |sextile Pluto Tau H9
# Saturn Cap H5 |square Venus Lib H2 H9
# Uranus Can H11 |square Neptune Ari H8
# Neptune Ari H8 |trine Sun Leo H12
# Neptune Ari H8 |square Uranus Can H11
# Pluto Tau H9 |square Sun Leo H12
# Pluto Tau H9 |trine Mercury Vir H1 H10
# Pluto Tau H9 |sextile Jupiter Can H11 H4 H7

# %%
symbol_output(key_array)
# Out:
# ☉ ♌︎ H12 |△ ♆ ♈︎ H8
# ☉ ♌︎ H12 |□ ♇ ♉︎ H9
# ☽ ♋︎ H11 |✶ ☿ ♍︎ H1 H10
# ☽ ♋︎ H11 |☌ ♃ H4 H7
# ☿ ♍︎ H1 |✶ ☽ ♋︎ H11 |✶ ♃ ♋︎ H11 H4 H7
# ☿ ♍︎ H1 |△ ♇ ♉︎ H9
# ♀ ♎︎ H2 |□ ♄ ♑︎ H5 H6
# ♃ ♋︎ H11 |☌ ☽
# ♃ ♋︎ H11 |✶ ☿ ♍︎ H1 H10 |✶ ♇ ♉︎ H9
# ♄ ♑︎ H5 |□ ♀ ♎︎ H2 H9
# ♅ ♋︎ H11 |□ ♆ ♈︎ H8
# ♆ ♈︎ H8 |△ ☉ ♌︎ H12
# ♆ ♈︎ H8 |□ ♅ ♋︎ H11
# ♇ ♉︎ H9 |□ ☉ ♌︎ H12
# ♇ ♉︎ H9 |△ ☿ ♍︎ H1 H10
# ♇ ♉︎ H9 |✶ ♃ ♋︎ H11 H4 H7
